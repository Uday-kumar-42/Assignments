-- %%
CREATE DATABASE BooksDB;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.445

-- %%
CREATE TABLE authors (
    author_id CHAR(4) PRIMARY KEY,
    first_name VARCHAR(30),
    last_name VARCHAR(30),
    city VARCHAR(30),
    state VARCHAR(20)
);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.015

-- %%
CREATE TABLE publishers (
    pub_id CHAR(4) PRIMARY KEY,
    pub_name VARCHAR(50),
    city VARCHAR(30),
    state VARCHAR(20),
    country VARCHAR(30)
);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.014

-- %%
CREATE TABLE titles (
    title_id CHAR(6) PRIMARY KEY,
    title VARCHAR(100),
    type VARCHAR(30),
    pub_id CHAR(4),
    price DECIMAL(6,2),
    royalty INT,
    ytd_sales INT,
    pubdate DATE,
    FOREIGN KEY (pub_id) REFERENCES publishers(pub_id)
);
-- Out:
-- : Msg 2714, Level 16, State 6, Line 1
-- There is already an object named 'titles' in the database.
-- Total execution time: 00:00:00.015

-- %%
CREATE TABLE title_author (
    title_id CHAR(6),
    author_id CHAR(4),
    author_order INT,
    royalty_share INT,
    PRIMARY KEY (title_id, author_id),
    FOREIGN KEY (title_id) REFERENCES titles(title_id),
    FOREIGN KEY (author_id) REFERENCES authors(author_id)
);
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.015

-- %%
INSERT INTO publishers VALUES
('0736','New Age Books','Boston','MA','USA'),
('0877','Tech Press','Menlo Park','CA','USA'),
('0911','Global Reads','London','NA','UK');
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.015

-- %%
INSERT INTO titles VALUES
('BU1111','Business Secrets','business','0736',20.00,15,12000,'2015-03-12',NULL),
('MC2222','Mind Control','psychology','0877',18.00,25,8000,'2018-06-10',NULL),
('CS3333','Coding Stars','technology','0877',30.00,10,15000,'2021-01-01',NULL),
('UN4444','Unknown Paths',NULL,'0911',NULL,5,3000,'1991-05-01',NULL);
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.024

-- %%
INSERT INTO authors VALUES
('A001','Sam','Smith','Menlo Park','CA'),
('A002','Dean','Brown','Boston','MA'),
('A003','Sara','Miles','Menlo Park','CA'),
('A004','John','Doe','New York','NY');
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.018

-- %%
INSERT INTO title_author VALUES
('BU1111','A001',1,60),
('BU1111','A002',2,40),
('MC2222','A003',1,100),
('CS3333','A001',1,50),
('CS3333','A003',2,50);
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.023

-- %%
-- 1. Add new column to products table that stores tax rate for the products update tax rate to 12% to all products.
ALTER TABLE titles ADD tax_rate INT;
UPDATE titles SET tax_rate = 12;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.019

-- %%
-- 2. Display tiles that End with 's'/'t'.
SELECT title
FROM titles
where title like '%s' OR title like '%t';
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.018
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr><tr><td>Unknown Paths</td></tr></table>

-- %%
-- 3. Display books of type business, psychology & undecided
SELECT title, type
FROM titles
WHERE type in ('business','psychology') OR type IS NULL;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>title</th><th>type</th></tr><tr><td>Business Secrets</td><td>business</td></tr><tr><td>Mind Control</td><td>psychology</td></tr><tr><td>Unknown Paths</td><td>NULL</td></tr></table>

-- %%
-- 4. Display titles where the sales>5,000 & royality<20.
SELECT title FROM titles
WHERE ytd_sales > 5000 AND royalty < 20;
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.020
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr></table>

-- %%
-- 5. Display titles in the ascending of sales for publisher 0736.
SELECT title , ytd_sales
FROM titles
WHERE pub_id = '0736'
ORDER BY ytd_sales ASC
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.017
-- <table><tr><th>title</th><th>ytd_sales</th></tr><tr><td>Business Secrets</td><td>12000</td></tr></table>

-- %%
-- 6. Display the difference between maximum & minimum royality of books published day publisher 0877.
SELECT MAX(royalty) - MIN(royalty) as diff_between_min_max
FROM titles 
WHERE pub_id = '0877';
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.018
-- <table><tr><th>diff_between_min_max</th></tr><tr><td>15</td></tr></table>

-- %%
-- 7. Display author_id & no of books written by Author.
SELECT author_id , 
COUNT(*) as no_of_books
FROM title_author
GROUP BY author_id;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>author_id</th><th>no_of_books</th></tr><tr><td>A001</td><td>2</td></tr><tr><td>A002</td><td>1</td></tr><tr><td>A003</td><td>2</td></tr></table>

-- %%
-- 8. Display how many authors are there for each title.
SELECT title_id , 
COUNT(*) as no_of_books
FROM title_author
GROUP BY title_id;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>title_id</th><th>no_of_books</th></tr><tr><td>BU1111</td><td>2</td></tr><tr><td>CS3333</td><td>2</td></tr><tr><td>MC2222</td><td>1</td></tr></table>

-- %%
-- 9. Display average royality % for authors with order 1.
SELECT AVG(royalty_share) as avg_royalty_share
FROM title_author
WHERE author_order = 1;
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>avg_royalty_share</th></tr><tr><td>70</td></tr></table>

-- %%
-- 10. Display titles in the order of price if sales are in the range 10k to 20k.
SELECT title
FROM titles
WHERE ytd_sales BETWEEN 10000 AND 20000
ORDER BY price
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr></table>

-- %%
-- 11. Display how many authors are in the city Menlo park.
SELECT CONCAT(COUNT(*),' authors') as no_of_authors_Menlo_Park
FROM authors
WHERE city = 'Menlo Park'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.012
-- <table><tr><th>no_of_authors_Menlo_Park</th></tr><tr><td>2 authors</td></tr></table>

-- %%
-- 12. Display state and no of authors we have in the state in the order of state.
SELECT state, COUNT(*) as count
FROM authors
GROUP BY state
ORDER BY state
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>state</th><th>count</th></tr><tr><td>CA</td><td>2</td></tr><tr><td>MA</td><td>1</td></tr><tr><td>NY</td><td>1</td></tr></table>

-- %%
-- 13. Display States in which we have more than 2 authors, with 1st name starting with 's'.
SELECT state , COUNT(*) as count
FROM authors
WHERE first_name LIKE 'S%' OR first_name LIKE 's%'
GROUP BY state
HAVING COUNT(*) >= 2
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.007
-- <table><tr><th>state</th><th>count</th></tr><tr><td>CA</td><td>2</td></tr></table>

-- %%
-- 14. Display title after replacing all spaces with (dots) and (hypens) with (stars).
SELECT REPLACE(REPLACE(title,' ','.'),'-','*') as formatted_titles
FROM titles;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>formatted_titles</th></tr><tr><td>Business.Secrets</td></tr><tr><td>Coding.Stars</td></tr><tr><td>Mind.Control</td></tr><tr><td>Unknown.Paths</td></tr></table>

-- %%
-- 15. Display title by Removing all spaces.
SELECT REPLACE(title,' ','.') as formatted_titles
FROM titles
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>formatted_titles</th></tr><tr><td>Business.Secrets</td></tr><tr><td>Coding.Stars</td></tr><tr><td>Mind.Control</td></tr><tr><td>Unknown.Paths</td></tr></table>

-- %%
-- 16. Display first word in the title.
SELECT SUBSTRING(TRIM(title),1,CHARINDEX(' ',TRIM(title)))
as formatted_titles
FROM titles;
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>formatted_titles</th></tr><tr><td>Business </td></tr><tr><td>Coding </td></tr><tr><td>Mind </td></tr><tr><td>Unknown </td></tr></table>

-- %%
-- 17. Display month and no of books published.
SELECT DATENAME(MONTH,pubdate) as month, COUNT(*) as no_of_books
FROM titles
GROUP BY DATENAME(MONTH,pubdate)
-- Out:
-- (4 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>month</th><th>no_of_books</th></tr><tr><td>January</td><td>1</td></tr><tr><td>June</td><td>1</td></tr><tr><td>March</td><td>1</td></tr><tr><td>May</td><td>1</td></tr></table>

-- %%
-- 18. Display title publisher name for titles where the publisher is in USA.
SELECT t.title , p.pub_name
FROM publishers p
INNER JOIN titles t
ON t.pub_id = p.pub_id
WHERE p.country = 'USA'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>title</th><th>pub_name</th></tr><tr><td>Business Secrets</td><td>New Age Books</td></tr><tr><td>Coding Stars</td><td>Tech Press</td></tr><tr><td>Mind Control</td><td>Tech Press</td></tr></table>

-- %%
-- 19. Display publisher name and average price of books.
SELECT p.pub_name , AVG(COALESCE(t.price,0)) as avg_book_price
FROM publishers p
INNER JOIN titles t
ON t.pub_id = p.pub_id
GROUP BY p.pub_name
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.013
-- <table><tr><th>pub_name</th><th>avg_book_price</th></tr><tr><td>Global Reads</td><td>0.000000</td></tr><tr><td>New Age Books</td><td>20.000000</td></tr><tr><td>Tech Press</td><td>24.000000</td></tr></table>

-- %%
-- 20. Display City of author and then no of books written by authors in the City.
SELECT a.author_id, a.city, COUNT(*) as no_of_books
FROM authors a
INNER JOIN title_author t
ON t.author_id = a.author_id
GROUP BY a.author_id , a.city
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>author_id</th><th>city</th><th>no_of_books</th></tr><tr><td>A001</td><td>Menlo Park</td><td>2</td></tr><tr><td>A002</td><td>Boston</td><td>1</td></tr><tr><td>A003</td><td>Menlo Park</td><td>2</td></tr></table>

-- %%
-- 21. Display auther name, title for all authors including the once without a title.
SELECT a.author_id, a.first_name, t.title_id, ti.title
FROM authors a
    LEFT JOIN title_author t
    ON t.author_id = a.author_id
    LEFT JOIN titles ti
    ON t.title_id = ti.title_id
-- Out:
-- (6 rows affected)
-- Total execution time: 00:00:00.003
-- <table><tr><th>author_id</th><th>first_name</th><th>title_id</th><th>title</th></tr><tr><td>A001</td><td>Sam</td><td>BU1111</td><td>Business Secrets</td></tr><tr><td>A001</td><td>Sam</td><td>CS3333</td><td>Coding Stars</td></tr><tr><td>A002</td><td>Dean</td><td>BU1111</td><td>Business Secrets</td></tr><tr><td>A003</td><td>Sara</td><td>CS3333</td><td>Coding Stars</td></tr><tr><td>A003</td><td>Sara</td><td>MC2222</td><td>Mind Control</td></tr><tr><td>A004</td><td>John</td><td>NULL</td><td>NULL</td></tr></table>

-- %%
-- 22. Display title publisher name and author name of the primary author.
SELECT p.pub_id, p.pub_name, ti.title, ta.author_id, a.first_name as primary_author
FROM publishers p
    INNER JOIN titles ti
    ON p.pub_id = ti.pub_id
    INNER JOIN title_author ta
    ON ta.title_id = ti.title_id
    INNER JOIN authors a
    ON a.author_id = ta.author_id
WHERE ta.author_order = 1;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.005
-- <table><tr><th>pub_id</th><th>pub_name</th><th>title</th><th>author_id</th><th>primary_author</th></tr><tr><td>0736</td><td>New Age Books</td><td>Business Secrets</td><td>A001</td><td>Sam</td></tr><tr><td>0877</td><td>Tech Press</td><td>Coding Stars</td><td>A001</td><td>Sam</td></tr><tr><td>0877</td><td>Tech Press</td><td>Mind Control</td><td>A003</td><td>Sara</td></tr></table>

-- %%
-- 23. Display City of publisher and maximum price of all titles.
SELECT p.pub_name , MAX(COALESCE(t.price,0)) as max_price
FROM publishers p
    INNER JOIN titles t
    ON p.pub_id = t.pub_id
GROUP BY p.pub_name
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.001
-- <table><tr><th>pub_name</th><th>max_price</th></tr><tr><td>Global Reads</td><td>0.00</td></tr><tr><td>New Age Books</td><td>20.00</td></tr><tr><td>Tech Press</td><td>30.00</td></tr></table>

-- %%
-- 24. Display titles written by any author in City (menlo park).
SELECT DISTINCT t.title
FROM titles t
JOIN title_author ta ON t.title_id = ta.title_id
JOIN authors a ON ta.author_id = a.author_id
WHERE a.city = 'Menlo Park'
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.011
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr><tr><td>Mind Control</td></tr></table>

-- %%
-- 25. Display publishers who published a titles in 1991.
SELECT DISTINCT p.pub_name
FROM publishers p
JOIN titles t ON p.pub_id = t.pub_id
WHERE YEAR(t.pubdate) = 1991
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>pub_name</th></tr><tr><td>Global Reads</td></tr></table>

-- %%
-- 26. Display titles not published in USA.
SELECT t.title
FROM titles t
JOIN publishers p ON t.pub_id = p.pub_id
WHERE p.country != 'USA'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.010
-- <table><tr><th>title</th></tr><tr><td>Unknown Paths</td></tr></table>

-- %%
-- 27. Display titles either published in USA (or) having price <5.
SELECT DISTINCT t.title
FROM titles t
JOIN publishers p ON t.pub_id = p.pub_id
WHERE p.country = 'USA'
   OR t.price < 5
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.016
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr><tr><td>Mind Control</td></tr></table>

-- %%
-- 28. create a view to contain title, publisher, year of publishing, price and type. Make sure when price is null display Zero and type is null display Unknown.
CREATE VIEW vw_title_details AS
SELECT 
    t.title,
    p.pub_name AS publisher,
    YEAR(t.pubdate) AS publish_year,
    COALESCE(t.price, 0) AS price,
    COALESCE(t.type, 'Unknown') AS type
FROM titles t
JOIN publishers p ON t.pub_id = p.pub_id
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.015

-- %%
-- 29. Display publishers who published books by author who wrote more than 2 titles.
SELECT DISTINCT p.pub_name
FROM publishers p
JOIN titles t ON p.pub_id = t.pub_id
JOIN title_author ta ON t.title_id = ta.title_id
WHERE ta.author_id IN (
    SELECT author_id
    FROM title_author
    GROUP BY author_id
    HAVING COUNT(title_id) >= 2
)
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.009
-- <table><tr><th>pub_name</th></tr><tr><td>New Age Books</td></tr><tr><td>Tech Press</td></tr></table>

-- %%
-- 30. Delete rows from title author for author with first_name as dean.
DELETE FROM title_author
WHERE author_id IN (
    SELECT author_id
    FROM authors
    WHERE first_name = 'Dean'
)
-- Out:
-- (0 rows affected)
-- Total execution time: 00:00:00.011

-- %%
-- 31. Update the price of the book BU1111 with the Price of book MC2222.
UPDATE titles
SET price = (
    SELECT price
    FROM titles
    WHERE title_id = 'MC2222'
)
WHERE title_id = 'BU1111'
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.015

-- %%
-- 32. Display titles published in last 25 years.
SELECT title
FROM titles
WHERE pubdate >= DATEADD(YEAR, -25, GETDATE());
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.014
-- <table><tr><th>title</th></tr><tr><td>Business Secrets</td></tr><tr><td>Coding Stars</td></tr><tr><td>Mind Control</td></tr></table>

-- %%
-- 33. Display titles published by any publisher who published a title in 2021.
SELECT title
FROM titles
WHERE pub_id IN (
    SELECT DISTINCT pub_id
    FROM titles
    WHERE YEAR(pubdate) = 2021
)
-- Out:
-- (2 rows affected)
-- Total execution time: 00:00:00.004
-- <table><tr><th>title</th></tr><tr><td>Coding Stars</td></tr><tr><td>Mind Control</td></tr></table>

-- %%
-- 34. Create a view to display publisher name, city, and no of books published.
CREATE VIEW vw_publisher_book_count AS
SELECT 
    p.pub_name,
    p.city,
    COUNT(t.title_id) AS book_count
FROM publishers p
LEFT JOIN titles t ON p.pub_id = t.pub_id
GROUP BY p.pub_name, p.city
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.004
